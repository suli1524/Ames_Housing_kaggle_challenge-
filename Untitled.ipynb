# %% [markdown]
# ## Ames Housing Project

# %% [markdown]
# ### Objective

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import StandardScaler,PolynomialFeatures,OneHotEncoder
from sklearn.metrics import r2_score,mean_squared_error

# %% [markdown]
# ### Read Data

# %%
# train Data
df_train = pd.read_csv('../project-2/datasets/train.csv')
df_train.head(0)
# Out:
# Empty DataFrame
# ...

# %%
# test Data
df_test = pd.read_csv('../project-2/datasets/test.csv')
df_test.head(0)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Exploring Data

# %%
df_train.shape
# Out:
# (2051, 81)

# %%
df_train.dtypes
# Out:
# Id                int64
# PID               int64
# MS SubClass       int64
# MS Zoning        object
# Lot Frontage    float64
#                  ...
# Misc Val          int64
# Mo Sold           int64
# Yr Sold           int64
# Sale Type        object
# SalePrice         int64
# Length: 81, dtype: object

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)
df_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
corr_matrix = df_train.corr()
# Out:
# C:\Users\sulai\AppData\Local\Temp\ipykernel_14428\1100942627.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_train.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix[['SalePrice']], annot=True, cmap='coolwarm', linewidths=0.5)
# Out:
# <Axes: >

# %%
df_train.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
df_train_cleaned = df_train[['Id','Overall Qual','Year Built', 'Year Remod/Add','Mas Vnr Area','Total Bsmt SF','1st Flr SF','Gr Liv Area','Full Bath','TotRms AbvGrd','Fireplaces','Garage Yr Blt','Garage Cars','Garage Area','SalePrice']]
df_train_cleaned.head()
# Out:
#     Id  Overall Qual  Year Built  Year Remod/Add  Mas Vnr Area  Total Bsmt SF  \
# 0  109             6        1976            2005         289.0          725.0
# 1  544             7        1996            1997         132.0          913.0
# 2  153             5        1953            2007           0.0         1057.0
# 3  318             5        2006            2007           0.0          384.0
# 4  255             6        1900            1993           0.0          676.0
#
#    1st Flr SF  Gr Liv Area  Full Bath  TotRms AbvGrd  Fireplaces  \
# 0         725         1479          2              6           0
# 1         913         2122          2              8           1
# 2        1057         1057          1              5           0
# 3         744         1444          2              7           0
# 4         831         1445          2              6           0
#
#    Garage Yr Blt  Garage Cars  Garage Area  SalePrice
# ...

# %%
df_train_cleaned.isna().sum()
# Out:
# Id                  0
# Overall Qual        0
# Year Built          0
# Year Remod/Add      0
# Mas Vnr Area       22
# Total Bsmt SF       1
# 1st Flr SF          0
# Gr Liv Area         0
# Full Bath           0
# TotRms AbvGrd       0
# Fireplaces          0
# Garage Yr Blt     114
# Garage Cars         1
# Garage Area         1
# SalePrice           0
# dtype: int64

# %%
df_train_cleaned = df_train_cleaned.dropna()

# %%
X = df_train_cleaned[['Overall Qual','Year Built', 'Year Remod/Add','Mas Vnr Area','Total Bsmt SF','1st Flr SF','Gr Liv Area','Full Bath','TotRms AbvGrd','Fireplaces','Garage Yr Blt','Garage Cars','Garage Area']]
X.head()
# Out:
#    Overall Qual  Year Built  Year Remod/Add  Mas Vnr Area  Total Bsmt SF  \
# 0             6        1976            2005         289.0          725.0
# 1             7        1996            1997         132.0          913.0
# 2             5        1953            2007           0.0         1057.0
# 3             5        2006            2007           0.0          384.0
# 4             6        1900            1993           0.0          676.0
#
#    1st Flr SF  Gr Liv Area  Full Bath  TotRms AbvGrd  Fireplaces  \
# 0         725         1479          2              6           0
# 1         913         2122          2              8           1
# 2        1057         1057          1              5           0
# 3         744         1444          2              7           0
# 4         831         1445          2              6           0
#
#    Garage Yr Blt  Garage Cars  Garage Area
# 0         1976.0          2.0        475.0
# 1         1997.0          2.0        559.0
# ...

# %%
y = df_train_cleaned['SalePrice']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %%
lr = LinearRegression()

# %%
y_hat = lr.fit(X_train,y_train)

# %%
y_train_pred = lr.predict(X_train)
y_train_pred
# Out:
# array([162726.39344575, 121023.36758893, 171011.29990407, ...,
#         55519.56545643, 140479.66914826, 126482.60559114])

# %%
y_test_pred = lr.predict(X_test)
y_test_pred;

# %%
print('training r2 = {}'.format(r2_score(y_train,y_train_pred)))
print('testing r2 = {}'.format(r2_score(y_test,y_test_pred)))
# Out:
# training r2 = 0.7782002287869139
# testing r2 = 0.8597552365129879

# %%
preds = lr.predict
